# %%
name = "Robin Ahmed"
age = 22
cgpa = 3.57

# %%
print(name)
print(age)
print(cgpa)
# Out:
# Robin Ahmed
# 22
# 3.57

# %%
name="Robin Ahmend Talukder"
age=25
height = 5.9
is_passed = True
print(type(name),type(age),type(height),type(is_passed)) # here bool means Boolean type
# bool can store only two type 1 and 0
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>
