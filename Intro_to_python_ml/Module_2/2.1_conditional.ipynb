# %%
raining = True 
if raining == True : 
    print("Rain Coat is necessary")
    print("Caution")
else: 
    print ("You can go without umbrella")
    print("This is a sunny day  ")
# Out:
# Rain Coat is necessary
# Caution

# %%
raining = False 
if raining == True : 
    print("Rain Coat is necessary")
    print("Caution")
else: 
    print ("You can go without umbrella")
    print("This is a sunny day  ")
# Out:
# You can go without umbrella
# This is a sunny day

# %%
rainning = True
muddy = False
if rainning == True : 
    print("Take your Umbrella")
    print("It's going to rain ")
    if muddy == True :
        print("You must take the hiking shoes ")
    else : 
        print("You can wear your snekers")
else: 
    print("You don't need umbrella ")
    print("It's a sunny day ")
# Out:
# Take your Umbrella
# It's going to rain
# You can wear your snekers

# %%
taka = int(input())
if taka > 1000 : 
    print ("I will go for shopping ")
elif taka>500:
    print("I will oder food at home ")
else:
    print("I will not buy anything ")
# Out:
# I will oder food at home

# %%
taka = 1000
rainning = True 
if (taka>500) and (rainning == False) :
    print("I will go outside for shopping")
else:
    print("I will save the money ")
# Out:
# I will save the money
