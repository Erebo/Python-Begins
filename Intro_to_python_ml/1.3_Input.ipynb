# %%
name = input("What is your name ? ")
print(name)
# Out:
# Mahadi

# %%
age=input("Your age?") # string hisebe input neowa 
print(age,"is taken as ",type(age),"data")
age = int(age) # typecasting 
print(type(age))
# Out:
# 22 is taken as  <class 'str'> data
# <class 'int'>

# %%
height=input("Your height ?")
print(height,type(height))
height=float(height)
print(type(height)) # if we don't use type caste then we can't use the input number for calculation
# Out:
# 5.67 <class 'str'>
# <class 'float'>

# %%
height=float(input("What is your height ? "))
height += 0.2
print(height,type(height))
# Out:
# 22.7 <class 'float'>
